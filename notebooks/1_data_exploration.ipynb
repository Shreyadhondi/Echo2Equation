# %% [markdown]
# <h1> Dwonloading the MathSpeech Dataset </h1>

# %%
from datasets import load_dataset

# Load the MathSpeech dataset (train split)
dataset = load_dataset("AAAI2025/MathSpeech", split="train")

# Check number of samples
print(f"Total samples: {len(dataset)}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/399 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/107M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1101 [00:00<?, ? examples/s]
# Total samples: 1101

# %% [markdown]
# <h2> Now let us visualize a few samples </h2>

# %%
# Convert to DataFrame (avoids triggering audio decoding)
dataset_df = dataset.to_pandas()

# Show the first 5 rows
dataset_df.head(5)
# Out:
#                                                audio  \
# 0  {'bytes': b'ID3\x03\x00\x00\x00\x00\x03%TFLT\x...
# 1  {'bytes': b'ID3\x03\x00\x00\x00\x00\x03%TFLT\x...
# 2  {'bytes': b'ID3\x03\x00\x00\x00\x00\x03%TFLT\x...
# 3  {'bytes': b'ID3\x03\x00\x00\x00\x00\x03%TFLT\x...
# 4  {'bytes': b'ID3\x03\x00\x00\x00\x00\x03%TFLT\x...
#
#                                        transcription  \
# 0                        ax plus by plus cz equals d
# 1                     x plus 5y plus 10z equals zero
# 2  x minus two y minus one and z plus one dot pro...
# 3  x minus two plus five times y minus one plus t...
# 4                        Ax plus By plus Cz equals D
#
#                                     LaTeX  \
# 0                      $ax + by + cz = d$
# 1                      $x + 5y + 10z = 0$
# 2            $[x-2,y-1,z+1]\cdot[1,5,10]$
# 3  $ (x - 2) + 5(y - 1) + 10(z + 1) = 0 $
# 4                      $Ax + By + Cz = D$
#
#                                         Source
# 0  https://www.youtube.com/watch?v=YBajUR3EFSM
# 1  https://www.youtube.com/watch?v=YBajUR3EFSM
# 2  https://www.youtube.com/watch?v=YBajUR3EFSM
# 3  https://www.youtube.com/watch?v=YBajUR3EFSM
# 4  https://www.youtube.com/watch?v=YBajUR3EFSM

# %% [markdown]
# <h2> Trimming the audip and the source columns. </h2>
# <h5> We do not need the audio and the sourse columns to train out model for our project, so i am just trimming it off. </h5>

# %%
import json

# Step 1: Select only the columns we need
trimmed_df = dataset_df[["transcription", "LaTeX"]]

# Step 2: Rename columns for consistency
trimmed_df = trimmed_df.rename(columns={"transcription": "spoken", "LaTeX": "latex"})

# Step 3: Save to JSONL file
output_path = "mathspeech_trimmed.jsonl"

with open(output_path, "w", encoding="utf-8") as f:
    for _, row in trimmed_df.iterrows():
        json.dump({"spoken": row["spoken"], "latex": row["latex"]}, f)
        f.write("\n")

print(f"Trimmed dataset saved to {output_path}")
# Out:
# Trimmed dataset saved to mathspeech_trimmed.jsonl

# %% [markdown]
# <h5> Let us preview our dataset </h5>

# %%
print(f"Total rows in trimmed dataset: {len(trimmed_df)}")
# Out:
# Total rows in trimmed dataset: 1101

# %%
# Show the first 5 rows of the trimmed dataset
trimmed_df.head(5)
# Out:
#                                               spoken  \
# 0                        ax plus by plus cz equals d
# 1                     x plus 5y plus 10z equals zero
# 2  x minus two y minus one and z plus one dot pro...
# 3  x minus two plus five times y minus one plus t...
# 4                        Ax plus By plus Cz equals D
#
#                                     latex
# 0                      $ax + by + cz = d$
# 1                      $x + 5y + 10z = 0$
# 2            $[x-2,y-1,z+1]\cdot[1,5,10]$
# 3  $ (x - 2) + 5(y - 1) + 10(z + 1) = 0 $
# 4                      $Ax + By + Cz = D$
